# %% [markdown]
# # Lecture 5: Supervised learning with CNNs
#
#
# We provide a collab with training and testing code for an MLP and a CNN model classifier.
#
#
# Task 1: Run both examples and discuss the performance difference.
#
#
# ### Train a small autotagging model
# In this section, we will train a small convolutional neural network (CNN) to perform music autotagging using a toy dataset.
#
# #### Steps:
# 1. Load and preprocess the dataset
# 2. Define the CNN model
# 3. Train the model
# 4. Evaluate the model

# %%
# !pip install torch
# !pip install mirdata
# !pip install tqdm
# !pip install scikit-learn
# !pip install torchaudio
# !pip install matplotlib
# Out:
# Collecting torch
#   Downloading torch-2.9.1-cp313-none-macosx_11_0_arm64.whl.metadata (30 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch) (80.9.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.9.1-cp313-none-macosx_11_0_arm64.whl (74.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 MB 42.7 MB/s  0:00:01m0:00:0100:01
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading networkx-3.6-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.0 MB/s  0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Installing collected packages: mpmath, sympy, networkx, jinja2, fsspec, filelock, torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [torch]32m6/7 [torch]]x]
# Successfully installed filelock-3.20.0 fsspec-2025.12.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6 sympy-1.14.0 torch-2.9.1
# Collecting mirdata
#   Using cached mirdata-1.0.0-py3-none-any.whl.metadata (9.1 kB)
# Collecting chardet>=5.0.0 (from mirdata)
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting Deprecated>=1.2.14 (from mirdata)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: h5py>=3.7.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from mirdata) (3.15.1)
# Collecting librosa>=0.10.1 (from mirdata)
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy>=1.21.6 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from mirdata) (2.3.5)
# Requirement already satisfied: pandas>=1.3.5 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from mirdata) (2.3.3)
# Collecting pretty_midi>=0.2.10 (from mirdata)
#   Using cached pretty_midi-0.2.11-py3-none-any.whl
# Collecting pyyaml>=6.0 (from mirdata)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting openpyxl>=3.0.10 (from mirdata)
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: scipy>=1.7.3 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from mirdata) (1.16.3)
# Collecting tqdm>=4.66.1 (from mirdata)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting smart_open>=5.0.0 (from smart_open[all]>=5.0.0->mirdata)
#   Downloading smart_open-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: wrapt<3,>=1.10 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from Deprecated>=1.2.14->mirdata) (2.0.1)
# Collecting audioread>=2.1.9 (from librosa>=0.10.1->mirdata)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa>=0.10.1->mirdata)
#   Using cached numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (2.8 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from librosa>=0.10.1->mirdata) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from librosa>=0.10.1->mirdata) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from librosa>=0.10.1->mirdata) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa>=0.10.1->mirdata)
#   Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa>=0.10.1->mirdata)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa>=0.10.1->mirdata)
#   Using cached soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from librosa>=0.10.1->mirdata) (4.15.0)
# Collecting lazy_loader>=0.1 (from librosa>=0.10.1->mirdata)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa>=0.10.1->mirdata)
#   Using cached msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting standard-aifc (from librosa>=0.10.1->mirdata)
#   Using cached standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa>=0.10.1->mirdata)
#   Using cached standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa>=0.10.1->mirdata) (25.0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.51.0->librosa>=0.10.1->mirdata)
#   Using cached llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.8 kB)
# Collecting et-xmlfile (from openpyxl>=3.0.10->mirdata)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pandas>=1.3.5->mirdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pandas>=1.3.5->mirdata) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pandas>=1.3.5->mirdata) (2025.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pooch>=1.1->librosa>=0.10.1->mirdata) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pooch>=1.1->librosa>=0.10.1->mirdata) (2.32.5)
# Collecting mido>=1.1.16 (from pretty_midi>=0.2.10->mirdata)
#   Using cached mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from pretty_midi>=0.2.10->mirdata) (1.17.0)
# Collecting importlib_resources (from pretty_midi>=0.2.10->mirdata)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.1->mirdata) (2025.11.12)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa>=0.10.1->mirdata) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from soundfile>=0.12.1->librosa>=0.10.1->mirdata) (2.0.0)
# Requirement already satisfied: pycparser in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.10.1->mirdata) (2.23)
# Collecting boto3>=1.9.17 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading boto3-1.42.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting google-cloud-storage>=2.6.0 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_cloud_storage-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting azure-storage-blob (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading azure_storage_blob-12.27.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-common (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-core (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached azure_core-1.36.0-py3-none-any.whl.metadata (47 kB)
# Collecting paramiko (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting backports.zstd>=1.0.0 (from smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading backports_zstd-1.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.9 kB)
# Collecting botocore<1.43.0,>=1.42.4 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading botocore-1.42.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.9.17->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting google-auth<3.0.0,>=2.26.1 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached google_crc32c-1.7.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (2.3 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (6.33.2)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage>=2.6.0->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from azure-storage-blob->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata) (46.0.3)
# Collecting isodate>=0.6.1 (from azure-storage-blob->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting bcrypt>=3.2 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting invoke>=2.0 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Using cached invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pynacl>=1.5 (from paramiko->smart_open>=5.0.0->smart_open[all]>=5.0.0->mirdata)
#   Downloading pynacl-1.6.1-cp38-abi3-macosx_10_10_universal2.whl.metadata (9.8 kB)
# Collecting standard-chunk (from standard-aifc->librosa>=0.10.1->mirdata)
#   Using cached standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa>=0.10.1->mirdata)
#   Using cached audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Using cached mirdata-1.0.0-py3-none-any.whl (263 kB)
# Using cached chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl (84 kB)
# Using cached numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl (2.7 MB)
# Using cached llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl (37.3 MB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached mido-1.3.3-py3-none-any.whl (54 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
# Using cached soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
# Using cached soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl (163 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading backports_zstd-1.2.0-cp313-cp313-macosx_11_0_arm64.whl (362 kB)
# Downloading boto3-1.42.4-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.4-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 35.7 MB/s  0:00:00eta 0:00:01
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading google_cloud_storage-3.6.0-py3-none-any.whl (299 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Using cached google_crc32c-1.7.1-cp313-cp313-macosx_12_0_arm64.whl (30 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Using cached azure_core-1.36.0-py3-none-any.whl (213 kB)
# Downloading azure_storage_blob-12.27.1-py3-none-any.whl (428 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached paramiko-4.0.0-py3-none-any.whl (223 kB)
# Using cached bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Using cached invoke-2.2.1-py3-none-any.whl (160 kB)
# Downloading pynacl-1.6.1-cp38-abi3-macosx_10_10_universal2.whl (387 kB)
# Using cached standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Using cached audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl (26 kB)
# Using cached standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Using cached standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: standard-chunk, azure-common, tqdm, soxr, smart_open, pyyaml, pyasn1, proto-plus, msgpack, mido, llvmlite, lazy_loader, jmespath, isodate, invoke, importlib_resources, googleapis-common-protos, google-crc32c, et-xmlfile, Deprecated, chardet, cachetools, bcrypt, backports.zstd, audioop-lts, standard-sunau, standard-aifc, soundfile, rsa, pynacl, pyasn1-modules, pretty_midi, pooch, openpyxl, numba, google-resumable-media, botocore, azure-core, s3transfer, paramiko, google-auth, azure-storage-blob, audioread, librosa, google-api-core, boto3, google-cloud-core, google-cloud-storage, mirdata
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49/49 [mirdata][mirdata][boto3]a]orage-blob]rotos]
# Successfully installed Deprecated-1.3.1 audioop-lts-0.2.2 audioread-3.1.0 azure-common-1.1.28 azure-core-1.36.0 azure-storage-blob-12.27.1 backports.zstd-1.2.0 bcrypt-5.0.0 boto3-1.42.4 botocore-1.42.4 cachetools-6.2.2 chardet-5.2.0 et-xmlfile-2.0.0 google-api-core-2.28.1 google-auth-2.43.0 google-cloud-core-2.5.0 google-cloud-storage-3.6.0 google-crc32c-1.7.1 google-resumable-media-2.8.0 googleapis-common-protos-1.72.0 importlib_resources-6.5.2 invoke-2.2.1 isodate-0.7.2 jmespath-1.0.1 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.45.1 mido-1.3.3 mirdata-1.0.0 msgpack-1.1.2 numba-0.62.1 openpyxl-3.1.5 paramiko-4.0.0 pooch-1.8.2 pretty_midi-0.2.11 proto-plus-1.26.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pynacl-1.6.1 pyyaml-6.0.3 rsa-4.9.1 s3transfer-0.16.0 smart_open-7.5.0 soundfile-0.13.1 soxr-1.0.0 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0 tqdm-4.67.1
# Requirement already satisfied: tqdm in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Collecting torchaudio
#   Downloading torchaudio-2.9.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (6.9 kB)
# Requirement already satisfied: torch==2.9.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torchaudio) (2.9.1)
# Requirement already satisfied: filelock in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (4.15.0)
# Requirement already satisfied: setuptools in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (3.6)
# Requirement already satisfied: jinja2 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from torch==2.9.1->torchaudio) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch==2.9.1->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from jinja2->torch==2.9.1->torchaudio) (3.0.3)
# Downloading torchaudio-2.9.1-cp313-cp313-macosx_12_0_arm64.whl (808 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.1/808.1 kB 17.0 MB/s  0:00:00
# Installing collected packages: torchaudio
# Successfully installed torchaudio-2.9.1
# Requirement already satisfied: matplotlib in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/meco/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import mirdata

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from torch.utils.data import DataLoader, Dataset
from torchaudio.transforms import MelSpectrogram, Resample
from tqdm import tqdm

# %% [markdown]
# ### Step 1: Load and preprocess the dataset
# We will use a toy dataset (e.g., ESC-10 or a similar audio dataset). The dataset will be preprocessed using PyTorch's DataLoader utilities.

# %%
dataset = mirdata.initialize("tinysol")
dataset.download()
split = dataset.get_random_track_splits([0.8, 0.2], split_names=("train", "val"))
train_ids, val_ids = split["train"], split["val"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dataset = mirdata.initialize("magnatagatune")
#       2 dataset.download()
#       3 split = dataset.get_random_track_splits([0.8, 0.2], split_names=("train", "val"))
#
# File ~/Library/CloudStorage/OneDrive-Personal/Educación/UPF/Cursos/Machine Learning for Music/Labs/.venv/lib/python3.13/site-packages/mirdata/__init__.py:70, in initialize(dataset_name, data_home, version)
#      45 """Load a mirdata dataset by name
#      46
#      47 Example:
#    (...)     67
#      68 """
#      69 if dataset_name not in DATASETS:
# ---> 70     raise ValueError("Invalid dataset {}".format(dataset_name))
#      72 module = importlib.import_module("mirdata.datasets.{}".format(dataset_name))
#      74 return module.Dataset(data_home=data_home, version=version)
#
# ValueError: Invalid dataset magnatagatune

# %%
class TinySOLDataset(Dataset):
    def __init__(self, mirdata_dataset, ids):
        self.orig_sample_rate = 44100
        self.sample_rate = 16000

        self.audio_duration = 3
        
        self.mirdata_dataset = mirdata_dataset
        self.tids = ids

        # Load audio and labels
        self.audio = {}
        self.natural_labels = {}

        self.resample = Resample(orig_freq=self.orig_sample_rate, new_freq=self.sample_rate)

        n_samples = self.sample_rate * self.audio_duration
        
        for tid in tqdm(ids, desc="Loading audio"):
            track = self.mirdata_dataset.track(tid)
            audio, sr = track.audio

            assert sr == self.orig_sample_rate
            audio = self.resample(torch.Tensor(audio))

            if len(audio) >= n_samples:
                audio = audio[:n_samples]
            else:
                pad_size = n_samples - len(audio)
                audio = torch.cat([audio, torch.zeros(pad_size)])
            
            self.audio[tid] = audio
            self.natural_labels[tid] = track.instrument_full

        # One hot encode labels
        natural_labels = np.array(list(self.natural_labels.values())).reshape(-1, 1)
        ohe = OneHotEncoder()
        one_hot_labels = ohe.fit_transform(natural_labels).toarray()
        self.labels = {k: v for k, v in zip(self.tids, one_hot_labels)}


    def __len__(self):
        return len(self.tids)

    def __getitem__(self, idx, audio_cap=4):
        # TODO audio_cap not used.
        tid = self.tids[idx]
        audio = self.audio[tid]
        labels = self.labels[tid]
        natural_labels = self.natural_labels[tid]
        
        return {"audio": audio, "labels": labels, "natural_labels": natural_labels}

train_dataset = TinySOLDataset(dataset, train_ids)
val_dataset = TinySOLDataset(dataset, val_ids)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
# Out:
# Loading audio: 100%|██████████| 2331/2331 [00:18<00:00, 123.47it/s]
# Loading audio: 100%|██████████| 582/582 [00:01<00:00, 443.12it/s]

# %% [markdown]
# ### Step 2: Define the CNN model
# We will define a simple CNN architecture suitable for music autotagging.

# %%
# Feature extractor. Using mel-spectrogram

class FeatureExtractor(nn.Module):
    def __init__(self, **kwargs):
        super().__init__() 
        self.melspectrogram = MelSpectrogram(**kwargs)

    def forward(self, x):
        x = self.melspectrogram(x)
        x = torch.log10(1 + 1000 * x)  # Log-compression
        return x

feature_extractor = FeatureExtractor(n_mels=64, n_fft=1024)

# %%
# Plot mel-spectrograms for debugging
import matplotlib.pyplot as plt

feature_extractor = FeatureExtractor(n_mels=64, n_fft=1024)

# Fetch a batch of data
batch = next(iter(train_loader))
mel_specs = feature_extractor(batch["audio"]).detach().numpy()
# Visualize the first three mel-spectrograms in the batch
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i in range(3):
    axes[i].imshow(mel_specs[i], aspect="auto", origin="lower")
    axes[i].set_title(f"Example {i+1}: {batch['natural_labels'][i]}")
plt.tight_layout()
plt.show()

# %%
n_classes = len(set(val_dataset.natural_labels.values()))

batch = next(iter(val_loader))
mels = feature_extractor(batch["audio"])

print("Mel-spectrogram shape:", mels.shape)
print("Number of classes:", n_classes)
# Out:
# Mel-spectrogram shape: torch.Size([32, 64, 94])
# Number of classes: 14

# %%
class MLP(nn.Module):
    def __init__(
        self,
        input_size,
        dense_size: int=64,
        n_classes: int=10,
    ):
        super().__init__()
        self.fc1 = nn.Linear(input_size, dense_size)
        self.fc2 = nn.Linear(dense_size, dense_size)
        self.fc3 = nn.Linear(dense_size, n_classes)

    def forward(self, x):
        x = torch.flatten(x, 1, 2)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class CNN(nn.Module):
    def __init__(
        self,
        kernel_size: int=3,
        pooling_size: int=4,
        dense_size: int=64,
        n_classes: int=10,
    ):
        super().__init__()
        self.dense_size = dense_size
        self.conv1 = nn.Conv2d(1, dense_size // 4, kernel_size=kernel_size, stride=1, padding=1)
        self.conv2 = nn.Conv2d(dense_size // 4, dense_size // 2, kernel_size=kernel_size, stride=1, padding=1)
        self.conv3 = nn.Conv2d(dense_size // 2, dense_size, kernel_size=kernel_size, stride=1, padding=1)
        
        self.pool = nn.MaxPool2d(kernel_size=pooling_size, stride=pooling_size)
        self.fc1 = nn.Linear(dense_size, dense_size)
        self.fc2 = nn.Linear(dense_size, n_classes)  # Assuming 10 classes

    def forward(self, x):
        x = x.unsqueeze(1)  # Add channel dimension: (32, 64, 94) -> (32, 1, 64, 94)
        x = self.pool(F.relu(self.conv1(x)))  # -> (32, 16, 64, 94) -> (32, 16, 16, 23)
        x = self.pool(F.relu(self.conv2(x)))  # -> (32, 32, 16, 23) -> (32, 32, 4, 5)
        x = self.pool(F.relu(self.conv3(x)))  # -> (32, 64, 4, 5) -> (32, 64, 1, 1)
        
        x = x.view(-1, self.dense_size)   # -> (32, 64)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Step 3: Train the models
# Set up the training loop with loss functions and optimizers.

# %%
# Training loop
def train(model, n_epochs=3, lr=0.001):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    for epoch in range(n_epochs):

        # Training loop
        model.train()
        for i, batch in enumerate(train_loader):
            x, y = batch["audio"], batch["labels"]
            
            optimizer.zero_grad()

            # Extract features and forward step
            x = feature_extractor(x)
            y_est = model(x)

            loss = criterion(y_est, y)
            loss.backward()
            optimizer.step()

        loss_train = loss.item()

        # Validation loop
        model.eval()
        accs = []
        for i, batch in enumerate(val_loader):
            x, y = batch["audio"], batch["labels"]
            
            # Extract features and forward model
            x = feature_extractor(x)
            y_est = model(x)
            
            loss = criterion(y_est, y)

            y_est = y_est.softmax(dim=1)
            y_int = torch.argmax(y, dim=1).numpy()
            y_est_int = torch.argmax(y_est, dim=1).numpy()
            accs.append(accuracy_score(y_int, y_est_int))
        
        acc_val = np.mean(accs)
        loss_val = loss.item()

        print(
            f'Epoch [{epoch + 1}/{n_epochs}], ' +
            f'Train loss: {loss_train:.4f}, ' +
            f'Val loss: {loss_val:.4f}, ' +
            f'Val acc.: {acc_val:.4f}'
        )

# %%
mlp = MLP(mels.shape[1] * mels.shape[2], dense_size=32, n_classes=n_classes)
num_params = sum(p.numel() for p in mlp.parameters() if p.requires_grad)
print(f"MLP parameters: {num_params}")

cnn = CNN(dense_size=128, n_classes=n_classes)
num_params = sum(p.numel() for p in cnn.parameters() if p.requires_grad)
print(f"CNN Trainable parameters: {num_params}")


print("\nTraining MLP model")
train(mlp, n_epochs=10)

print("\nTraining CNN model")
train(cnn, n_epochs=10)
# Out:
# MLP parameters: 194062
# CNN Trainable parameters: 110990
#
# Training MLP model
# Epoch [1/10], Train loss: 1.6111, Val loss: 0.6987, Val acc.: 0.5833
# Epoch [2/10], Train loss: 0.9513, Val loss: 0.3125, Val acc.: 0.6491
# Epoch [3/10], Train loss: 0.7127, Val loss: 0.2459, Val acc.: 0.7050
# Epoch [4/10], Train loss: 0.6099, Val loss: 0.1795, Val acc.: 0.7352
# Epoch [5/10], Train loss: 0.8480, Val loss: 0.4709, Val acc.: 0.7379
# Epoch [6/10], Train loss: 0.6945, Val loss: 0.2681, Val acc.: 0.8026
# Epoch [7/10], Train loss: 0.7504, Val loss: 0.2538, Val acc.: 0.7955
# Epoch [8/10], Train loss: 0.3699, Val loss: 0.1792, Val acc.: 0.8306
# Epoch [9/10], Train loss: 0.4634, Val loss: 0.1459, Val acc.: 0.8158
# Epoch [10/10], Train loss: 0.5124, Val loss: 0.0591, Val acc.: 0.8388
#
# Training CNN model
# Epoch [1/10], Train loss: 1.4805, Val loss: 0.9159, Val acc.: 0.5159
# Epoch [2/10], Train loss: 1.2156, Val loss: 0.6111, Val acc.: 0.6738
# Epoch [3/10], Train loss: 0.5004, Val loss: 0.1446, Val acc.: 0.7429
# Epoch [4/10], Train loss: 0.4724, Val loss: 0.2685, Val acc.: 0.7823
# Epoch [5/10], Train loss: 0.4285, Val loss: 0.0775, Val acc.: 0.7944
# Epoch [6/10], Train loss: 0.1624, Val loss: 0.0216, Val acc.: 0.8503
# Epoch [7/10], Train loss: 0.1866, Val loss: 0.0257, Val acc.: 0.8454
# Epoch [8/10], Train loss: 0.1231, Val loss: 0.0418, Val acc.: 0.8717
# Epoch [9/10], Train loss: 0.3407, Val loss: 0.3026, Val acc.: 0.8481
# Epoch [10/10], Train loss: 0.0810, Val loss: 0.0112, Val acc.: 0.9194
